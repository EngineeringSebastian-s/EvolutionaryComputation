# %%
# !pip uninstall torch torchvision torchaudio ultralytics -y
# Out:
# Found existing installation: torch 2.5.1+cu121
# Uninstalling torch-2.5.1+cu121:
#   Successfully uninstalled torch-2.5.1+cu121
# Found existing installation: torchvision 0.20.1+cu121
# Uninstalling torchvision-0.20.1+cu121:
#   Successfully uninstalled torchvision-0.20.1+cu121
# Found existing installation: ultralytics 8.4.48
# Uninstalling ultralytics-8.4.48:
#   Successfully uninstalled ultralytics-8.4.48
# WARNING: Skipping torchaudio as it is not installed.

# %%
# !pip install --force-reinstall torch torchvision --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch
#   Using cached https://download-r2.pytorch.org/whl/cu121/torch-2.5.1%2Bcu121-cp311-cp311-win_amd64.whl (2449.4 MB)
# Collecting torchvision
#   Using cached https://download-r2.pytorch.org/whl/cu121/torchvision-0.20.1%2Bcu121-cp311-cp311-win_amd64.whl (6.1 MB)
# Collecting filelock (from torch)
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Using cached https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting numpy (from torchvision)
#   Using cached numpy-2.4.3-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached https://download.pytorch.org/whl/markupsafe-3.0.3-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pillow-12.1.1-cp311-cp311-win_amd64.whl (7.0 MB)
# Using cached https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached https://download.pytorch.org/whl/markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached numpy-2.4.3-cp311-cp311-win_amd64.whl (12.6 MB)
# Installing collected packages: mpmath, typing-extensions, sympy, pillow, numpy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
#
#   Attempting uninstall: mpmath
#
#     Found existing installation: mpmath 1.3.0
#
#    ----------------------------------------  0/12 [mpmath]
#     Uninstalling mpmath-1.3.0:
#    ----------------------------------------  0/12 [mpmath]
#       Successfully uninstalled mpmath-1.3.0
#    ----------------------------------------  0/12 [mpmath]
#    ----------------------------------------  0/12 [mpmath]
#    ----------------------------------------  0/12 [mpmath]
#    ----------------------------------------  0/12 [mpmath]
#    ----------------------------------------  0/12 [mpmath]
#    ----------------------------------------  0/12 [mpmath]
#    ----------------------------------------  0/12 [mpmath]
#    ----------------------------------------  0/12 [mpmath]
#   Attempting uninstall: typing-extensions
#    ----------------------------------------  0/12 [mpmath]
#     Found existing installation: typing_extensions 4.15.0
#    ----------------------------------------  0/12 [mpmath]
#     Uninstalling typing_extensions-4.15.0:
#    ----------------------------------------  0/12 [mpmath]
#    --- ------------------------------------  1/12 [typing-extensions]
#    --- ------------------------------------  1/12 [typing-extensions]
#    --- ------------------------------------  1/12 [typing-extensions]
#    --- ------------------------------------  1/12 [typing-extensions]
#    --- ------------------------------------  1/12 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    --- ------------------------------------  1/12 [typing-extensions]
#   Attempting uninstall: sympy
#    --- ------------------------------------  1/12 [typing-extensions]
#    ------ ---------------------------------  2/12 [sympy]
#     Found existing installation: sympy 1.13.1
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#     Uninstalling sympy-1.13.1:
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#       Successfully uninstalled sympy-1.13.1
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#    ------ ---------------------------------  2/12 [sympy]
#   Attempting uninstall: pillow
#    ------ ---------------------------------  2/12 [sympy]
#     Found existing installation: pillow 12.1.1
#    ------ ---------------------------------  2/12 [sympy]
#    ---------- -----------------------------  3/12 [pillow]
#     Uninstalling pillow-12.1.1:
#    ---------- -----------------------------  3/12 [pillow]
#       Successfully uninstalled pillow-12.1.1
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#    ---------- -----------------------------  3/12 [pillow]
#   Attempting uninstall: numpy
#    ---------- -----------------------------  3/12 [pillow]
#     Found existing installation: numpy 2.4.3
#    ---------- -----------------------------  3/12 [pillow]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#     Uninstalling numpy-2.4.3:
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#       Successfully uninstalled numpy-2.4.3
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#    ------------- --------------------------  4/12 [numpy]
#   Attempting uninstall: networkx
#    ------------- --------------------------  4/12 [numpy]
#    ---------------- -----------------------  5/12 [networkx]
#     Found existing installation: networkx 3.6.1
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#     Uninstalling networkx-3.6.1:
#    ---------------- -----------------------  5/12 [networkx]
#       Successfully uninstalled networkx-3.6.1
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#    ---------------- -----------------------  5/12 [networkx]
#   Attempting uninstall: MarkupSafe
#    ---------------- -----------------------  5/12 [networkx]
#     Found existing installation: MarkupSafe 3.0.3
#    ---------------- -----------------------  5/12 [networkx]
#     Uninstalling MarkupSafe-3.0.3:
#    ---------------- -----------------------  5/12 [networkx]
#       Successfully uninstalled MarkupSafe-3.0.3
#    ---------------- -----------------------  5/12 [networkx]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#    -------------------- -------------------  6/12 [MarkupSafe]
#   Attempting uninstall: fsspec
#    -------------------- -------------------  6/12 [MarkupSafe]
#     Found existing installation: fsspec 2026.2.0
#    -------------------- -------------------  6/12 [MarkupSafe]
#     Uninstalling fsspec-2026.2.0:
#    -------------------- -------------------  6/12 [MarkupSafe]
#       Successfully uninstalled fsspec-2026.2.0
#    -------------------- -------------------  6/12 [MarkupSafe]
#    ----------------------- ----------------  7/12 [fsspec]
#    ----------------------- ----------------  7/12 [fsspec]
#    ----------------------- ----------------  7/12 [fsspec]
#    ----------------------- ----------------  7/12 [fsspec]
#    ----------------------- ----------------  7/12 [fsspec]
#    ----------------------- ----------------  7/12 [fsspec]
#   Attempting uninstall: filelock
#    ----------------------- ----------------  7/12 [fsspec]
#     Found existing installation: filelock 3.25.2
#    ----------------------- ----------------  7/12 [fsspec]
#     Uninstalling filelock-3.25.2:
#    ----------------------- ----------------  7/12 [fsspec]
#    -------------------------- -------------  8/12 [filelock]
#       Successfully uninstalled filelock-3.25.2
#    -------------------------- -------------  8/12 [filelock]
#    -------------------------- -------------  8/12 [filelock]
#   Attempting uninstall: jinja2
#    -------------------------- -------------  8/12 [filelock]
#     Found existing installation: Jinja2 3.1.6
#    -------------------------- -------------  8/12 [filelock]
#     Uninstalling Jinja2-3.1.6:
#    -------------------------- -------------  8/12 [filelock]
#       Successfully uninstalled Jinja2-3.1.6
#    -------------------------- -------------  8/12 [filelock]
#    ------------------------------ ---------  9/12 [jinja2]
#    ------------------------------ ---------  9/12 [jinja2]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    --------------------------------- ------ 10/12 [torch]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ------------------------------------ --- 11/12 [torchvision]
#    ---------------------------------------- 12/12 [torchvision]
#
# Successfully installed MarkupSafe-3.0.3 filelock-3.25.2 fsspec-2026.2.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 numpy-2.4.3 pillow-12.1.1 sympy-1.13.1 torch-2.5.1+cu121 torchvision-0.20.1+cu121 typing-extensions-4.15.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\.venv\Lib\site-packages\~-rkupsafe'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.4.48-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (2.34.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (1.40.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.40.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.40.1)
# Requirement already satisfied: six>=1.5 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: filelock in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Using cached ultralytics-8.4.48-py3-none-any.whl (1.2 MB)
# Installing collected packages: ultralytics
# Successfully installed ultralytics-8.4.48
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install roboflow
# Out:
# Requirement already satisfied: roboflow in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (1.3.8)
# Requirement already satisfied: certifi in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (2026.4.22)
# Requirement already satisfied: idna==3.7 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (3.10.9)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (2.4.3)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (12.1.1)
# Requirement already satisfied: pi-heif<2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (1.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (2.34.0)
# Requirement already satisfied: six in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (2.7.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer>=0.12.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from roboflow) (0.25.1)
# Requirement already satisfied: colorama in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from typer>=0.12.0->roboflow) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from typer>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from typer>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from typer>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib->roboflow) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib->roboflow) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from requests->roboflow) (3.4.7)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install load_dotenv
# Out:
# Requirement already satisfied: load_dotenv in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (0.1.0)
# Requirement already satisfied: python-dotenv in c:\users\sebastian-edu\documents\github\evolutionarycomputation\.venv\lib\site-packages (from load_dotenv) (1.2.2)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import ultralytics
from IPython.display import clear_output
from ultralytics import YOLO
import torch
from PIL import Image
from roboflow import Roboflow
import matplotlib.pyplot as plt

ultralytics.checks()
clear_output()

# %%
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "Ninguna")
# Out:
# True
# NVIDIA T500

# %%
DRIVE_URL = '/content/drive'
LOCAL_PATH = os.getcwd()

# %%
def detect_environment():
    try:
        ipython_env = str(get_ipython())

        if 'google.colab' in ipython_env:
            return "Google Colab"
        elif 'zmqshell' in ipython_env:
            return "Jupyter Notebook Local"
        else:
            return "Terminal interactiva de Python"
    except NameError:
        return "Script de Python estándar (.py)"


print(f"Entorno detectado: {detect_environment()}")
# Out:
# Entorno detectado: Jupyter Notebook Local

# %%
if detect_environment() != "Google Colab":
    BASE = LOCAL_PATH
else:
    BASE = DRIVE_URL
    from google.colab import drive
    drive.mount('/content/drive')
    from google.colab import userdata

# %%
BASE_IMGS = os.path.join(BASE, "imgs")
BASE_MODELS = os.path.join(BASE, "models")
BASE_DATA = os.path.join(BASE, "data")
BASE_RESULTS = os.path.join(BASE, "results")
BASE_PROJECT = os.path.join(BASE_DATA, "bccd-1")

# %%
os.makedirs(BASE_IMGS, exist_ok=True)
os.makedirs(BASE_MODELS, exist_ok=True)
os.makedirs(BASE_DATA, exist_ok=True)
os.makedirs(BASE_RESULTS, exist_ok=True)
os.makedirs(BASE_PROJECT, exist_ok=True)

# %%
model_n= YOLO(os.path.join(BASE_MODELS, "yolov8n.pt"))

# %%
result_n = model_n.predict(os.path.join(BASE_IMGS, "imagen_yolo.jpg"))
# Out:
# image 1/1 C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\imgs\imagen_yolo.jpg: 384x640 15 persons, 8 chairs, 4 tvs, 13 laptops, 1 mouse, 1 keyboard, 1 cell phone, 73.3ms
# Speed: 3.4ms preprocess, 73.3ms inference, 20.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
result_n[0].names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
result_n[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([ 0., 56.,  0.,  0., 56., 63., 56., 56.,  0., 63.,  0., 56.,  0., 64., 62., 66., 63.,  0.,  0., 63., 62.,  0.,  0.,  0.,  0.,  0., 63., 63., 63., 63., 62., 63., 62., 63.,  0., 63., 56., 63., 56., 67.,  0., 63., 56.], device='cuda:0')
# conf: tensor([0.9000, 0.8309, 0.7724, 0.7669, 0.7464, 0.7436, 0.6796, 0.6588, 0.6244, 0.5915, 0.5911, 0.5597, 0.5512, 0.5447, 0.5372, 0.5201, 0.5134, 0.5041, 0.5000, 0.4919, 0.4675, 0.4631, 0.4598, 0.4131, 0.4018, 0.3993, 0.3988, 0.3968, 0.3963, 0.3769, 0.3679, 0.3543, 0.3534, 0.3514, 0.3514, 0.3490, 0.3197, 0.3149, 0.3135,
#         [  79.0778,  309.3470,   82.3992,   88.2097],
#         [ 166.4919,  294.3522,   85.2702,   63.1438],
#         [ 493.0644,  287.5445,  112.2549,  133.2010],
#         [ 902.6432,  338.5833,   81.0687,  156.6595],
#         [ 612.2659,  251.8743,   89.2493,   75.7695],
#         [ 225.5844,  293.7310,   93.5944,  115.3829],
#         [1176.2542,  353.2757,  171.9702,  270.3053],
#         [ 418.1518,  462.7350,  158.1048,  176.6961],
#         [ 336.4998,  269.0721,   48.5775,   42.8142],
#         [1104.7841,  264.0867,   46.8179,   60.4362],
#         [ 762.0055,  314.6376,   44.8977,   66.9276],
#         [ 337.0092,  269.2563,   50.1325,   41.6462],
#         [ 491.6232,  329.6664,  112.7916,   53.8010],
#         [1251.0449,  276.0447,   56.4922,   65.1566],
#         [ 773.4034,  316.3850,   71.6455,   74.6967],
#         [ 689.8029,  238.4965,   51.6056,   76.9829],
#         [ 648.4445,  299.1035,  107.4102,   50.5271],
#         [ 785.5613,  644.5276,  233.7449,  149.2781],
#         [ 248.2727,  455.5013,  190.1136,  209.7018],
#         [ 976.4211,  412.0914,   68.3875,  108.3829],
#         [ 467.4377,  593.3890,   58.0190,   40.4886],
#         [ 493.6604,  267.7171,  109.3975,   92.2344],
#         [ 913.9349,  246.9012,   39.5275,   32.4466],
#         [1174.8264,  342.7587,  130.8018,  125.2724]], device='cuda:0')
# xywhn: tensor([[0.5097, 0.7288, 0.3139, 0.5272],
#         [0.0645, 0.6559, 0.1282, 0.3263],
#         [0.3028, 0.3921, 0.0703, 0.1885],
#         [0.6746, 0.6068, 0.1265, 0.4217],
#         [0.6513, 0.8938, 0.1073, 0.2104],
#         [0.1302, 0.4078, 0.0676, 0.0870],
#         [0.8199, 0.4872, 0.0804, 0.1802],
#         [0.7316, 0.7653, 0.1191, 0.3557],
#         [0.1546, 0.4116, 0.1147, 0.1695],
#         [0.9778, 0.3856, 0.0435, 0.0899],
#         [0.6082, 0.3227, 0.0449, 0.0665],
#         [0.3250, 0.4654, 0.0342, 0.0862],
#         [0.8143, 0.3926, 0.0682, 0.1764],
#         [0.3433, 0.8927, 0.0215, 0.0415],
#         [0.3269, 0.6423, 0.1236, 0.2474],
#         [0.4035, 0.7757, 0.1212, 0.1691],
#         [0.6285, 0.4180, 0.0583, 0.1148],
#         [0.8022, 0.4066, 0.0878, 0.2025],
#         [0.2400, 0.4865, 0.1053, 0.2031],
#         [0.0618, 0.4296, 0.0644, 0.1225],
#         [0.1301, 0.4088, 0.0666, 0.0877],
#         [0.3852, 0.3994, 0.0877, 0.1850],
#         [0.7052, 0.4703, 0.0633, 0.2176],
#         [0.4783, 0.3498, 0.0697, 0.1052],
#         [0.1762, 0.4080, 0.0731, 0.1603],
#         [0.9189, 0.4907, 0.1344, 0.3754],
#         [0.3267, 0.6427, 0.1235, 0.2454],
#         [0.2629, 0.3737, 0.0380, 0.0595],
#         [0.8631, 0.3668, 0.0366, 0.0839],
#         [0.5953, 0.4370, 0.0351, 0.0930],
#         [1.3968e-01, 3.2783e-01, 2.1280e-01, 4.8809e-01],
#         [8.5177e-01, 3.0295e-01, 9.8612e-01, 6.7837e-01],
#         [2.6492e-01, 5.1998e-01, 3.8844e-01, 7.6539e-01],
#         [2.4391e-01, 3.4398e-01, 2.8187e-01, 4.0344e-01],
#         [8.4482e-01, 3.2482e-01, 8.8140e-01, 4.0876e-01],
#         [5.7778e-01, 3.9052e-01, 6.1285e-01, 4.8347e-01],
#         [2.4371e-01, 3.4505e-01, 2.8287e-01, 4.0289e-01],
#         [3.4002e-01, 4.2051e-01, 4.2814e-01, 4.9523e-01],
#         [9.5531e-01, 3.3815e-01, 9.9945e-01, 4.2864e-01],
#         [5.7623e-01, 3.8755e-01, 6.3221e-01, 4.9130e-01],
#         [5.1875e-01, 2.7778e-01, 5.5907e-01, 3.8471e-01],
#         [4.6464e-01, 3.8033e-01, 5.4855e-01, 4.5051e-01],
#         [5.2241e-01, 7.9151e-01, 7.0503e-01, 9.9884e-01],
#         [1.1970e-01, 4.8701e-01, 2.6823e-01, 7.7827e-01],
#         [7.3612e-01, 4.9708e-01, 7.8954e-01, 6.4762e-01],
#         [3.4252e-01, 7.9603e-01, 3.8785e-01, 8.5227e-01],
#         [3.4294e-01, 3.0778e-01, 4.2841e-01, 4.3588e-01],
#         [6.9857e-01, 3.2039e-01, 7.2945e-01, 3.6545e-01],
#         [8.6674e-01, 3.8906e-01, 9.6893e-01, 5.6305e-01]], device='cuda:0')

# %%
for r in result_n:
    im_array = r.plot(line_width=2)
    im_rgb = im_array[...,::-1]
    im = Image.fromarray(im_rgb)
    plt.imshow(im_rgb)
    plt.axis('off')
    plt.show()
    im.save(os.path.join(BASE_IMGS, "detection_n.jpg"))

# %% [markdown]
# # Entrenamiento de Modelo

# %%
model_s= YOLO(os.path.join(BASE_MODELS, "yolov8s.pt"))
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\models\yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 2.5MB/s 8.7s8.7s<0.1s4s

# %%
def setup_roboflow_credentials():
    env = detect_environment()
    api_key = None

    if env == "colab":
        try:
            api_key = userdata.get('ROBOFLOW_API_KEY')
            print("Credenciales de Roboflow cargadas desde Secretos de Colab.")
        except Exception:
            print("Configura 'ROBOFLOW_API_KEY' en los secretos de Colab.")
    else:
        try:
            from dotenv import load_dotenv
            load_dotenv()
        except ImportError:
            print("python-dotenv no está instalado. Usando variables de entorno del sistema...")

        api_key = os.environ.get('ROBOFLOW_API_KEY')

        if api_key:
            print("Credenciales de Roboflow cargadas desde variables de entorno (.env).")
        else:
            print("No se encontró 'ROBOFLOW_API_KEY' en el entorno local.")

    return api_key

# %%
rf_api_key = setup_roboflow_credentials()
# Out:
# Credenciales de Roboflow cargadas desde variables de entorno (.env).

# %%
if rf_api_key:
    try:
        rf = Roboflow(api_key=rf_api_key)

        workspace_name = 'yolov8-rdmbf'
        project_name = 'bccd-f0tcy'

        print(f"Descargando proyecto '{project_name}' del workspace '{workspace_name}'...")

        project = rf.workspace(workspace_name).project(project_name)
        version = project.version(1)
        os.chdir(BASE_DATA)
        dataset = version.download("yolov8")
        os.chdir(BASE)
        print("Dataset descargado correctamente en:", BASE_DATA)

    except Exception as e:
        print(f"Ocurrió un error al conectar con Roboflow: {e}")
else:
    print("Ejecución detenida: No hay credenciales válidas para Roboflow.")
# Out:
# Descargando proyecto 'bccd-f0tcy' del workspace 'yolov8-rdmbf'...
# loading Roboflow workspace...
# loading Roboflow project...
# Dataset descargado correctamente en: C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\data

# %%
result= model_s.train(data=os.path.join(BASE_PROJECT, "data.yaml"), project= BASE_RESULTS, name='bccd_custom_training', epochs=10, imgsz=416, batch=8,device=0, amp=False, workers=4, cache=True, optimizer='auto')
# Out:
# Ultralytics 8.4.48  Python-3.11.2 torch-2.5.1+cu121 CUDA:0 (NVIDIA T500, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=False, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\data\bccd-1\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\models\yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=bccd_custom_training-5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\results, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\results\bccd_custom_training-5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,136,761 parameters, 11,136,745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.1 ms, read: 27.414.6 MB/s, size: 15.5 KB)
# train: Scanning C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\data\bccd-1\train\labels.cache... 2250 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2250/2250  0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (1.1GB RAM): 100% ━━━━━━━━━━━━ 2250/2250 2.1Kit/s 1.1s0.1s
# val: Fast image access  (ping: 0.30.1 ms, read: 25.43.2 MB/s, size: 12.9 KB)
# val: Scanning C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\data\bccd-1\valid\labels.cache... 73 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 73/73  0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.0GB RAM): 100% ━━━━━━━━━━━━ 73/73 1.6Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\results\bccd_custom_training-5\labels.jpg...
# Image sizes 416 train, 416 val
# Using 4 dataloader workers
# Logging results to C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\results\bccd_custom_training-5
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      1.82G      1.293       1.18      1.338         24        416: 100% ━━━━━━━━━━━━ 282/282 2.0it/s 2:21<1.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2s/it 5.8s1.4ss
#                    all         73        967      0.849      0.908       0.91      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      1.91G      1.207     0.8674      1.229         20        416: 100% ━━━━━━━━━━━━ 282/282 1.1s/it 5:05<1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2s/it 5.8s1.6ss
#                    all         73        967      0.816      0.919       0.91      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      1.91G       1.18     0.8361      1.199         11        416: 100% ━━━━━━━━━━━━ 282/282 1.6s/it 7:40<1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.3s1.7ss
#                    all         73        967      0.833      0.883      0.909      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      1.91G      1.153      0.801      1.181         16        416: 100% ━━━━━━━━━━━━ 282/282 1.1s/it 5:21<1.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 4.9s1.3ss
#                    all         73        967      0.854        0.9      0.922      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      1.91G      1.131     0.7695      1.168         24        416: 100% ━━━━━━━━━━━━ 282/282 1.1s/it 5:08<1.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1it/s 4.7s1.3ss
#                    all         73        967      0.837       0.92      0.913      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      1.92G       1.11     0.7417      1.158         37        416: 100% ━━━━━━━━━━━━ 282/282 1.0s/it 4:45<1.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1it/s 4.7s1.3ss
#                    all         73        967      0.829      0.929      0.927      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      1.92G      1.089     0.7174      1.145         22        416: 100% ━━━━━━━━━━━━ 282/282 1.5s/it 7:02<1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1s/it 10.5s.5ss
#                    all         73        967      0.887      0.898      0.926      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      1.92G      1.072      0.696      1.131         25        416: 100% ━━━━━━━━━━━━ 282/282 1.7s/it 7:58<1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.4s/it 7.1s1.8ss
#                    all         73        967      0.839      0.926      0.926      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      1.92G      1.047     0.6707      1.115         22        416: 100% ━━━━━━━━━━━━ 282/282 1.5s/it 7:02<1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2s/it 6.0s1.6ss
#                    all         73        967      0.858      0.902      0.929      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      1.92G      1.022     0.6462      1.108         16        416: 100% ━━━━━━━━━━━━ 282/282 1.8s/it 8:20<1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2s/it 6.0s1.6ss
#                    all         73        967      0.861      0.916      0.936      0.648
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 result= model_s.train(data=os.path.join(BASE_PROJECT, "data.yaml"), project= BASE_RESULTS, name='bccd_custom_training', epochs=10, imgsz=416, batch=8,device=0, amp=False, workers=4, cache=True, optimizer='auto')
#
# File ~\Documents\GitHub\EvolutionaryComputation\.venv\Lib\site-packages\ultralytics\engine\model.py:792, in Model.train(self, trainer, **kwargs)
#     789     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     790     self.model = self.trainer.model
# --> 792 self.trainer.train()
#     793 # Update model and cfg after training
#     794 if RANK in {-1, 0}:
#
# File ~\Documents\GitHub\EvolutionaryComputation\.venv\Lib\site-packages\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File ~\Documents\GitHub\EvolutionaryComputation\.venv\Lib\site-packages\ultralytics\engine\trainer.py:537, in BaseTrainer._do_train(self)
#     534         self.stop |= (time.time() - self.train_time_start) > (self.args.time * 3600)
#     536     # Save model
# --> 537     if (self.args.save or final_epoch) and self.save_model():
#     538         self.run_callbacks("on_model_save")
#     540 # Scheduler
#
# File ~\Documents\GitHub\EvolutionaryComputation\.venv\Lib\site-packages\ultralytics\engine\trainer.py:671, in BaseTrainer.save_model(self)
#     669 # Save checkpoints
#     670 self.wdir.mkdir(parents=True, exist_ok=True)  # ensure weights directory exists
# --> 671 self.last.write_bytes(serialized_ckpt)  # save last.pt
#     672 if self.best_fitness == self.fitness:
#     673     self.best.write_bytes(serialized_ckpt)  # save best.pt
#
# File pathlib.py:1067, in Path.write_bytes(self, data)
#
# File pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\Sebastian-EDU\\Documents\\GitHub\\EvolutionaryComputation\\RoboFlow\\results\\bccd_custom_training-5\\weights\\last.pt'

# %%
result_l = model_s.predict(os.path.join(BASE_IMGS, "imagen_yolo.jpg"), save= True, show=False, conf=0.25)
# Out:
# image 1/1 C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\RoboFlow\imgs\imagen_yolo.jpg: 384x640 6 -s, 83.2ms
# Speed: 9.0ms preprocess, 83.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\Sebastian-EDU\Documents\GitHub\EvolutionaryComputation\runs\detect\predict

# %%
result_l[0].names
# Out:
# {0: '-',
#  1: 'BCCD - v4 416x416_aug',
#  2: 'This dataset was exported via roboflow.com on January 13- 2023 at 5-48 PM GMT'}

# %%
result_l[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0., 0., 0., 0.], device='cuda:0')
# conf: tensor([0.5191, 0.5139, 0.4469, 0.3460, 0.3452, 0.2763], device='cuda:0')
# data: tensor([[1.5305e+01, 3.5097e+02, 1.6851e+02, 4.9395e+02, 5.1910e-01, 0.0000e+00],
#         [3.2868e+02, 2.1679e+02, 4.6543e+02, 3.7053e+02, 5.1391e-01, 0.0000e+00],
#         [3.6125e+02, 5.8090e+02, 5.2984e+02, 7.1846e+02, 4.4690e-01, 0.0000e+00],
#         [4.0391e+02, 4.1964e+00, 4.9806e+02, 1.4212e+02, 3.4598e-01, 0.0000e+00],
#         [6.5035e+02, 3.8345e+02, 7.9262e+02, 5.4661e+02, 3.4523e-01, 0.0000e+00],
#         [8.0531e+02, 3.6600e+02, 9.4792e+02, 4.6280e+02, 2.7625e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (720, 1280)
# shape: torch.Size([6, 6])
# xywh: tensor([[ 91.9082, 422.4596, 153.2061, 142.9857],
#         [397.0558, 293.6632, 136.7439, 153.7371],
#         [445.5459, 649.6765, 168.5917, 137.5607],
#         [450.9863,  73.1594,  94.1523, 137.9258],
#         [721.4869, 465.0297, 142.2721, 163.1647],
#         [876.6144, 414.3988, 142.6187,  96.8059]], device='cuda:0')
# xywhn: tensor([[0.0718, 0.5867, 0.1197, 0.1986],
#         [0.3102, 0.4079, 0.1068, 0.2135],
#         [0.3481, 0.9023, 0.1317, 0.1911],
#         [0.3523, 0.1016, 0.0736, 0.1916],
#         [0.5637, 0.6459, 0.1112, 0.2266],
#         [0.6849, 0.5756, 0.1114, 0.1345]], device='cuda:0')
# xyxy: tensor([[ 15.3052, 350.9667, 168.5113, 493.9524],
#         [328.6838, 216.7946, 465.4277, 370.5317],
#         [361.2500, 580.8961, 529.8417, 718.4568],
#         [403.9102,   4.1964, 498.0624, 142.1223],
#         [650.3508, 383.4473, 792.6229, 546.6121],
#         [805.3051, 365.9958, 947.9237, 462.8018]], device='cuda:0')
# xyxyn: tensor([[0.0120, 0.4875, 0.1316, 0.6860],
#         [0.2568, 0.3011, 0.3636, 0.5146],
#         [0.2822, 0.8068, 0.4139, 0.9979],
#         [0.3156, 0.0058, 0.3891, 0.1974],
#         [0.5081, 0.5326, 0.6192, 0.7592],
#         [0.6291, 0.5083, 0.7406, 0.6428]], device='cuda:0')

# %%
for r in result_l:
    im_array = r.plot(line_width=2)
    im_rgb = im_array[...,::-1]
    im = Image.fromarray(im_rgb)
    plt.imshow(im_rgb)
    plt.axis('off')
    plt.show()
    im.save(os.path.join(BASE_IMGS, "detection_s.jpg"))
